# %% [markdown]
# # **Python für Ingenieure**
# <!-- Lizensiert unter (CC BY 2.0) Gert Herold, 2020 -->
# # 8. Plotten mit [Matplotlib](https://matplotlib.org/)
#
# ## 8.1. Statische Plot-Beispiele
#
# Importieren von matplotlibs Matlab-ähnlicher API:

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### 8.1.1. [*plot()*](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.plot.html)
#
# Einfacher Plot:

# %%
y = [3,2,7,5]

plt.plot(y)
plt.show()

# %% [markdown]
# Einfacher $x$-$y$-Plot:

# %%
x = [-0.1,0.2,0.7,2.5]
y = [3,2,7,5]

plt.plot(x, y)
plt.show()

# %% [markdown]
# Format-Strings zur einfachen Auswahl der [Marker](https://matplotlib.org/api/markers_api.html), Linien, und [Farbe](https://matplotlib.org/tutorials/colors/colors.html):

# %%
x = [-0.1,0.2,0.7,2.5]
y = [3,2,7,5]

#plt.plot(x, y, 'ro:')
#plt.plot(x, y, 'bo:')
#plt.plot(x, y, 'r')
#plt.plot(x, y, 'go:')
#plt.plot(x, y, color = 'red', linestyle = 'dotted', marker='o', linewidth=1.5, markersize=6)

plt.plot(x, y, c = 'red', ls = 'dotted', marker='o', lw=1.5, ms=20)
#plt.plot(x, y, ':o', c = (1,0,0)) # RGB-Farben
#plt.plot(x, y, ':o', c = 'C0') # mpl-Standard-Farben

plt.show()

# %% [markdown]
# Mehrere Kurven plotten, inkl. [Legende](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.legend.html):

# %%
import numpy as np
np.random.seed(1)
kurvenname = ['blau', 'orange', 'grün', 'rot', 'lila']

x = np.arange(10)
y = np.random.randn(5,10)

#'''
for i in range(5):
    plt.plot(x,y[i], label = kurvenname[i])
plt.legend()
#plt.legend(loc='upper right')
#plt.legend(loc='lower center')

'''
plt.plot(x,y.T)
plt.legend(kurvenname)
#''' 
   

plt.show()

# %% [markdown]
# ### 8.1.2. [*scatter()*](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.scatter.html)

# %%
import numpy as np
np.random.seed(1)

x = np.random.randn(10)
y = np.random.randn(10)
val = abs(np.random.randn(10)*100)

#plt.scatter(x,y)
#plt.scatter(x,y,s=val)
plt.scatter(x,y,c=val); plt.colorbar()
plt.show()
# fahrbbar ??
# farhbige Punkte

# %% [markdown]
# ### 8.1.3. Plotgröße
#
# Hierfür eine Abbildung mit [*figure()*](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.figure.html) erstellen.
#
# `figsize` : (Breite, Höhe) in Zoll

# %%
plt.figure(num=1,figsize=(15,3))
x = [-0.1,0.2,0.7,2.5]
y = [3,2,7,5]
plt.plot(x, y, 'ro:')
plt.show()

# %% [markdown]
# ### 8.1.4. [*savefig()*](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.savefig.html)
#
# Abspeichern von Plots

# %%
plt.figure(2,(4,3))
x = [-0.1,0.2,0.7,2.5]
y = [3,2,7,5]
plt.plot(x, y, 'ro:')

plt.savefig('ein_plot.png') 
#plt.savefig('ein_plot.pdf') 
#plt.savefig('ein_plot.eps') 
#plt.savefig('ein_plot_hires.png',dpi=1000)

# %% [markdown]
# Weißen Rand entfernen

# %%
plt.figure(3,(4,3))
x = [-0.1,0.2,0.7,2.5]
y = [3,2,7,5]
plt.plot(x, y, 'ro:')

plt.savefig('ein_plot_ohne_rand1.png', bbox_inches='tight',transparent=True)
#transparent=True ?

# %% [markdown]
# Weißen Rand entfernen bei gleichbleibender Abbildungsgröße

# %%
plt.figure(4,(4,3))

x = [-0.1,0.2,0.7,2.5]
y = [3,2,7,5]
plt.plot(x, y, 'ro:')

plt.tight_layout()

plt.savefig('ein_plot_ohne_rand2.png')

# %%
plt.figure(4,(4,3))

x = [-0.1,0.2,0.7,2.5]
y = [3,2,7,5]
plt.plot(x, y, 'ro:')

plt.subplots_adjust(left=0.05, right=0.99, top=1.0, bottom=0.075)

plt.savefig('ein_plot_ohne_rand3.png')

# %% [markdown]
# ### 8.1.4. Subplots
#
# [*subplot()*](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.subplot.html)

# %%
x = [-0.1,0.2,0.7,2.5]
y = [3,2,7,5]

plt.figure(4,(8,5))

plt.subplot(2,3,1)
plt.plot(x, y, 'ro:')

plt.subplot(2,3,3)
plt.plot(x, y, 'og')

plt.subplot(234)
plt.plot(x, y, '^')

plt.subplot(235)
plt.plot(x, y, '--k')

plt.show()

# %% [markdown]
# [*subplots_adjust()*](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.subplots_adjust.html)

# %%
x = [-0.1,0.2,0.7,2.5]
y = [3,2,7,5]

# plot im verschiedene Fahrben
for sp in range(1,7):
    plt.subplot(2,3,sp)
    plt.plot(x,y,c='C%d'%(sp-1))
    
plt.show()

# %%
x = [-0.1,0.2,0.7,2.5]
y = [3,2,7,5]

plt.figure(4,(8,5))

plt.subplot(2,3,1)
plt.plot(x, y, 'ro:')

plt.subplot(2,3,3)
plt.plot(x, y, 'og')

plt.subplot(234)
plt.plot(x, y, '^')

plt.subplot(235)
plt.plot(x, y, '--k')

plt.subplots_adjust(left=0.05, right=0.99, top=1.0, bottom=0.075, wspace=0.6, hspace=0.01)
plt.show()

# %% [markdown]
# ### 8.1.5. Achsen
#
# Beschriftung
# ****
# ### 8.1.5. axes
#
# labeling

# %%
x = [-0.1,0.2,0.7,2.5]
y = [3,2,7,5]

plt.plot(x, y, 'ro:')
plt.xlabel('$\\xi_{gesamt}$ / m')
plt.ylabel('T / K')
plt.show()

# %% [markdown]
# Limits

# %%
x = [-0.1,0.2,0.7,2.5]
y = [3,2,7,5]

plt.plot(x, y, 'ro:')
plt.xlim(0.5,1.5)
plt.ylim([4,10])
plt.show()

# %% [markdown]
# Skala

# %%
x = [-0.1,0.2,0.7,2.5]
y = [3,2,7,5]

plt.plot(x, y, 'ro:')
plt.xticks(np.linspace(-0.2,2.6,15))
plt.yticks(range(2,8),['A','','B','B 1/2','C'])
plt.grid(True)
plt.show()

# %% [markdown]
# Skalierung

# %%
x = [0.1,0.2,0.7,2.5]
y = [3,2,7,5]

'''
plt.semilogx(x, y, 'ro:')
'''
plt.plot(x, y, 'ro:')
plt.xscale('log')
plt.yscale('log')
#'''

plt.show()
