# %% [markdown]
# # **Python für Ingenieure**
# <!-- Lizensiert unter (CC BY 2.0) Gert Herold, 2019 -->
# ## 4.3. Übungsaufgaben

# %% [markdown]
# **1) Berechnen Sie einen gewichteten Mittelwert der Zahlen im folgenden Dictionary. Werte, bei denen der Schlüssel mit einem "!" endet, sollen doppelt gewichtet werden. Vergleichen Sie mit dem ungewichteten Mittelwert.**
# ********************
# ** 1) Calculate a weighted average of the numbers in the following dictionary. Values where the key is marked with a "!" ends should be weighted twice. Compare with the unweighted average. **

# %%
messwerte = {'2018-10-19 20:58:17' : 29.52,
             '2018-10-19 23:31:09' : 41.72,
             '2018-10-19 18:27:14' : 13.68,
             '2018-10-20 00:23:12' : 27.39,
             '2018-10-19 21:24:47!': 21.92,
             '2018-10-20 00:23:12' : 27.39,
             '2018-10-19 21:24:47!': 21.92,
             '2018-10-20 01:37:01' : 34.70,
             '2018-10-19 19:43:20!': 20.85,
             '2018-10-19 20:31:55!': 29.27,
             '2018-10-19 23:57:24' : 27.28,
             '2018-10-19 19:17:05!': 47.96,
             '2018-10-19 23:06:13' : 18.15,
             '2018-10-19 18:01:29' : 30.15,
             '2018-10-20 00:48:26!': 20.16,
             '2018-10-19 22:39:59!': 25.25,
             '2018-10-19 21:49:38' : 27.05,
             '2018-10-19 20:07:21' : 39.39,
             '2018-10-19 18:52:01' : 32.54,
             '2018-10-19 17:37:20' : 20.06,
             '2018-10-19 22:14:07!': 33.50,
             '2018-10-20 01:13:07!': 41.34,
            
             '2018-10-33 22:39:59!': 25.25,
             '2018-10-19 21:49:38' : 27.05,
             '2018-10-19 20:07:21' : 39.39,
             '2018-10-22 18:52:01' : 32.54,
             '2018-10-11 17:37:20' : 20.06,
             '2018-10-19 22:14:11!': 33.50,
             '2018-10-20 01:13:07!': 41.34}
print (len(messwerte))  
#number of keys
# Out:
# 24

# %%
messwerte = {'2018-10-19 20:58:17' : 29.52,
             '2018-10-19 23:31:09' : 41.72,
             '2018-10-19 18:27:14' : 13.68,
             '2018-10-20 00:23:12' : 27.39,
             '2018-10-19 21:24:47!': 21.92,
             '2018-10-20 01:37:01' : 34.70,
             '2018-10-19 19:43:20!': 20.85,
             '2018-10-19 20:31:55!': 29.27,
             '2018-10-19 23:57:24' : 27.28,
             '2018-10-19 19:17:05!': 47.96,
             '2018-10-19 23:06:13' : 18.15,
             '2018-10-19 18:01:29' : 30.15,
             '2018-10-20 00:48:26!': 20.16,
             '2018-10-19 22:39:59!': 25.25,
             '2018-10-19 21:49:38' : 27.05,
             '2018-10-19 20:07:21' : 39.39,
             '2018-10-19 18:52:01' : 32.54,
             '2018-10-19 17:37:20' : 20.06,
             '2018-10-19 22:14:07!': 33.50,
             '2018-10-20 01:13:07!': 41.34}



# Hier eigenen Code schreiben ...
summe = 0
wichtung = len(messwerte)
for i in messwerte:
    summe += messwerte[i]
    if i[-1] == '!': 
        wichtung += 1
        summe += messwerte[i]

summe/wichtung, sum(messwerte.values())/len(messwerte)
# Out:
# (29.361785714285705, 29.094)

# %% [markdown]
# **2) Geben Sie das obige Dictionary als zeitlich sortierte Tabelle *ohne* "!" aus.**
# ***********
# ** 2) Enter the above dictionary as a chronologically sorted table * without * "!" out.**
# *******************
# ** 2) أدخل القاموس أعلاه كجدول مصنف ترتيبًا زمنيًا * بدون * "!" إيقاف. **
#
# ```
#  |  2018-10-19 17:37:20  |  20.06  |
#  |  2018-10-19 18:01:29  |  30.15  |
#  ...
# ```

# %%
###wichtig ###   sorted 

#sorted?
# Hier eigenen Code schreiben ...
for i in sorted(messwerte):
    print('|  %s  |  %5.2f  |' %(i   [0:len('2018-10-19 18:01:29')], messwerte[i]  )   )
# Out:
# |  2018-10-19 17:37:20  |  20.06  |
# |  2018-10-19 18:01:29  |  30.15  |
# |  2018-10-19 18:27:14  |  13.68  |
# |  2018-10-19 18:52:01  |  32.54  |
# |  2018-10-19 19:17:05  |  47.96  |
# |  2018-10-19 19:43:20  |  20.85  |
# |  2018-10-19 20:07:21  |  39.39  |
# |  2018-10-19 20:31:55  |  29.27  |
# |  2018-10-19 20:58:17  |  29.52  |
# |  2018-10-19 21:24:47  |  21.92  |
# |  2018-10-19 21:49:38  |  27.05  |
# |  2018-10-19 22:14:07  |  33.50  |
# |  2018-10-19 22:39:59  |  25.25  |
# |  2018-10-19 23:06:13  |  18.15  |
# |  2018-10-19 23:31:09  |  41.72  |
# |  2018-10-19 23:57:24  |  27.28  |
# |  2018-10-20 00:23:12  |  27.39  |
# |  2018-10-20 00:48:26  |  20.16  |
# |  2018-10-20 01:13:07  |  41.34  |
# |  2018-10-20 01:37:01  |  34.70  |

# %% [markdown]
# **3) Geben Sie die Messzeiten aus, zu denen die `n` geringsten Werte gemessen wurden.**
# **********************
#
# Hinweis: Variablen lassen sich mit
# ```python
# del mein_variablenname
# ```
# löschen.
# ******
# ** 3) Enter the measuring times at which the `n` lowest values were measured. **
# ***************
# Note: Variables can be used with
# ```python
# del my_Variables names
# ```
# Clear.
# ******

# %%
n = 3
messkopie = messwerte.copy()
# Hier eigenen Code schreiben ...
v = 1000
vi =''

for i in range(n):

    for i in messkopie:
        if messkopie[i]==min(messkopie.values()): 
            print(i)
            del messkopie[i]
            break
# Out:
# 2018-10-19 18:27:14
# 2018-10-19 23:06:13
# 2018-10-19 17:37:20

# %%
messkopie
# Out:
# {'2018-10-19 20:58:17': 29.52,
#  '2018-10-19 23:31:09': 41.72,
#  '2018-10-20 00:23:12': 27.39,
#  '2018-10-19 21:24:47!': 21.92,
#  '2018-10-20 01:37:01': 34.7,
#  '2018-10-19 19:43:20!': 20.85,
#  '2018-10-19 20:31:55!': 29.27,
#  '2018-10-19 23:57:24': 27.28,
#  '2018-10-19 19:17:05!': 47.96,
#  '2018-10-19 18:01:29': 30.15,
#  '2018-10-20 00:48:26!': 20.16,
#  '2018-10-19 22:39:59!': 25.25,
#  '2018-10-19 21:49:38': 27.05,
#  '2018-10-19 20:07:21': 39.39,
#  '2018-10-19 18:52:01': 32.54,
#  '2018-10-19 22:14:07!': 33.5,
#  '2018-10-20 01:13:07!': 41.34}

# %% [markdown]
# ###wichtig###
# ******************
#
# **4) Wieviel [Zeit](https://docs.python.org/3/library/time.html) (in Minuten) vergeht jeweils zwischen zwei aufeinanderfolgenden Messungen?**
# *************************
# ** 4) How much [time](https://docs.python.org/3/library/time.html) (in minutes) elapses between two successive measurements? **
# *****
# ** 4) ما مقدار الوقت [الوقت](https://docs.python.org/3/library/time.html) (بالدقائق) بين قياسين متتاليين؟ **

# %%
#####??????????????

import time
#time.strptime?
silvester = time.strptime('31.12.2019, 23:59 Uhr','%d.%m.%Y, %H:%M Uhr')
print(silvester)
print('\nZu Silvester vergangene Sekunden seit 1.1.1970:',time.mktime(silvester))
# Hier eigenen Code schreiben ...

alte_sekunden = 0
for zeit in sorted(messwerte):
    zeitstempel = zeit[:19]
    ##???
    neue_sekunden = time.mktime(time.strptime(zeitstempel,'%Y-%m-%d %H:%M:%S'))
    vergangen = neue_sekunden-alte_sekunden
    if vergangen<10000: print(vergangen/60)
    alte_sekunden = neue_sekunden
# Out:
# time.struct_time(tm_year=2019, tm_mon=12, tm_mday=31, tm_hour=23, tm_min=59, tm_sec=0, tm_wday=1, tm_yday=365, tm_isdst=-1)
#
# Zu Silvester vergangene Sekunden seit 1.1.1970: 1577833140.0
# 24.15
# 25.75
# 24.783333333333335
# 25.066666666666666
# 26.25
# 24.016666666666666
# 24.566666666666666
# 26.366666666666667
# 26.5
# 24.85
# 24.483333333333334
# 25.866666666666667
# 26.233333333333334
# 24.933333333333334
# 26.25
# 25.8
# 25.233333333333334
# 24.683333333333334
# 23.9

# %% [markdown]
# ###wichtig###
# ******************
#
# **5) Schreiben Sie ein kurzes Programm, das den Nutzer nach einem Datum fragt und daraufhin eine Aussage über den Wochentag zurückgibt. Unterscheiden Sie, ob das Datum in der Zukunft oder Vergangenheit liegt.**
#
# Beispiele:
# ```
#  Der 03.10.1990 war ein Mittwoch.
#  Der 01.05.2048 ist ein Freitag.
# ```
# *******************
# ** 5) Write a short program that asks the user for a date and then returns a statement about the day of the week. Distinguish whether the date is in the future or in the past. **
#
# Examples:
# ''
#   The 03.10.1990 was a Wednesday.
#   05/01/2048 is a Friday.
# ''
# ******************
# ** 5) اكتب برنامجًا قصيرًا يسأل المستخدم عن تاريخ ثم يعيد بيانًا عن يوم الأسبوع. ميّز ما إذا كان التاريخ في المستقبل أو في الماضي. **
#
# أمثلة:
# ''
#   كان 03.10.1990 يوم الأربعاء.
#   05/01/2048 هي يوم الجمعة.
# ''

# %%
###wichtig ### 
###########

import time
print('Heute:',time.gmtime())
wochentage = ['Montag', 'Dienstag', 'Mittwoch', 'Donnerstag', 'Freitag', 'Samstag', 'Sonntag']

# Hier eigenen Code schreiben ...
datum = input("Gib ein Datum ein im Format DD.MM.YYYY:")
date = time.strptime(datum,'%d.%m.%Y')

if date[:3]<time.gmtime()[:3]:
    wort = 'war'
else:
    wort = 'ist'
print("Der %s %s ein %s." % (datum, wort, wochentage[date.tm_wday]))
# Out:
# Heute: time.struct_time(tm_year=2020, tm_mon=9, tm_mday=15, tm_hour=22, tm_min=11, tm_sec=17, tm_wday=1, tm_yday=259, tm_isdst=0)
# Gib ein Datum ein im Format DD.MM.YYYY: 01.01.1981
# Der 01.01.1981 war ein Donnerstag.

# %%
wochentage[time.gmtime().tm_wday]
# Out:
# 'Dienstag'

# %%
import time
print('Heute:',time.gmtime())
# Out:
# Heute: time.struct_time(tm_year=2020, tm_mon=9, tm_mday=15, tm_hour=22, tm_min=12, tm_sec=32, tm_wday=1, tm_yday=259, tm_isdst=0)
