# %% [markdown]
# # Hausaufgabe 1
# ## Lärmbelastung am Arbeitsplatz
# <!-- Lizensiert unter (CC BY 2.0) Gert Herold, 2019 -->
#
# Für die Beurteilung der tagsüber auftretenden Lärmbelastung in einem Gewerbegebiet wurden über mehrere Monate an Werktagen der Mittelungspegel $L_\text{A,eq}$ an einem Immissionsort bestimmt.
#
#
# # Homework 1
# ## Noise pollution at the workplace
# <! - Licensed under (CC BY 2.0) Gert Herold, 2019 ->
#
# For the assessment of the daytime noise exposure in a commercial area, the averaging level $ L_ \ text {A, eq} $ at an immission location was determined over several months on working days.

# %%
LAeq = {'Januar': [65.6473, 63.6885, 63.3891, 66.0919, 64.1625, 66.4128, 61.4494, 50.8258, 68.1941, 73.9349, 65.2068, 
                   62.4992, 62.3178, 62.4047, 63.087, 57.3899, 60.4145, 58.0149, 64.244, 61.5168, 65.4761, 62.1265], 
        'Februar': [67.9317, 64.0677, 73.9535, 53.5182, 59.7654, 67.5074, 75.6416, 61.7568, 63.2183, 61.8684, 
                    69.6573, 61.5635, 66.4003, 61.401, 56.6372, 64.5677, 65.5159, 69.4661, 62.4478, 59.9132], 
        'März': [65.8138, 64.2037, 64.4033, 62.6344, 68.8017, 64.8475, 72.5233, 68.5553, 66.2952, 54.8628, 
                 66.0116, 65.1014, 67.0548, 68.2222, 60.9956, 67.12, 60.1885, 72.7744, 56.3402, 54.1966], 
        'April': [54.7464, 58.5472, 57.4044, 72.7804, 61.3675, 56.2866, 68.5719, 60.0674, 56.8157, 67.3792, 
                  66.1168, 60.8252, 70.0377, 63.6455, 71.0847, 65.5137, 70.794, 63.547, 56.9013, 75.2468], 
        'Mai': [60.2711, 62.0058, 59.498, 61.983, 64.2133, 64.0092, 66.3051, 71.9608, 62.3977, 56.8344, 57.0884, 
                59.6712, 54.629, 67.1251, 60.5089, 61.4451, 62.9905, 56.0169, 58.6934, 66.3736, 66.0927], 
        'Juni': [60.7841, 72.0527, 56.4714, 61.2751, 61.8458, 49.0346, 72.6876, 64.8317, 57.7771, 73.2559, 
                 65.9283, 65.1476, 59.965, 63.5311, 55.3716, 66.9751, 61.1278, 63.6702, 69.0103]}

# %% [markdown]
# **1. Geben Sie für jeden Monat den jeweils höchsten Pegel mit einer Nachkommastelle als Fließtext an.**
#
# Beispiel:
#
#     Im August wurde ein maximaler Mittelungspegel von 75.2 dB gemessen.
#
# *(Für einen Hinweis zur Textformatierung unter Python den ausgeblendeten Abschnitt öffnen)*
#
#
#
# **1. For each month, enter the highest level with one decimal place as the text. **
#
# Example:
#
#      In August, a maximum averaging level of 75.2 dB was measured.
#
# * (For a note about text formatting under Python, open the hidden section) *
#
# ***1- Find the highest LAeq for each month.

# %%
# Hinweis: Zeichketten in Python mit formatierenden Platzhaltern -- verschiedene Wege zum gleichen Ziel
s = 'Sekunde'
m = 'Minute'
h = 'Stunde'
s_per_m = 60
h_per_m = 1/60

print('%04d: Eine %s hat %d %sn. Das sind %8.4f %sn. Eine %s entspricht demnach %.6f %sn.' % (1, m, s_per_m, s, h_per_m, h, s, h_per_m/s_per_m, h))
print('{:04d}: Eine {} hat {} {}n. Das sind {:8.4f} {}n. Eine {} entspricht demnach {:.6f} {}n.'.format(2, m, s_per_m, s, h_per_m, h, s, h_per_m/s_per_m, h))
print(f'{3:04d}: Eine {m} hat {s_per_m} {s}n. Das sind {h_per_m:8.4f} {h}n. Eine {s} entspricht demnach {h_per_m/s_per_m:.6f} {h}n.')

print('%04d:'% (2))
print('%.4f:'% (1.221552))
# Out:
# 0102: Eine Minute hat 60 Sekunden. Das sind   0.0167 Stunden. Eine Sekunde entspricht demnach 0.000278 Stunden.
# 0002: Eine Minute hat 60 Sekunden. Das sind   0.0167 Stunden. Eine Sekunde entspricht demnach 0.000278 Stunden.
# 0003: Eine Minute hat 60 Sekunden. Das sind   0.0167 Stunden. Eine Sekunde entspricht demnach 0.000278 Stunden.
# 0002:
# 1.2216:

# %%
# Hier eigenen Code schreiben ...

LAeq = {'Januar': [65.6473, 63.6885, 63.3891, 66.0919, 64.1625, 66.4128, 61.4494, 50.8258, 68.1941, 73.9349, 65.2068, 
                   62.4992, 62.3178, 62.4047, 63.087, 57.3899, 60.4145, 58.0149, 64.244, 61.5168, 65.4761, 62.1265], 
        'Februar': [67.9317, 64.0677, 73.9535, 53.5182, 59.7654, 67.5074, 75.6416, 61.7568, 63.2183, 61.8684, 
                    69.6573, 61.5635, 66.4003, 61.401, 56.6372, 64.5677, 65.5159, 69.4661, 62.4478, 59.9132], 
        'März': [65.8138, 64.2037, 64.4033, 62.6344, 68.8017, 64.8475, 72.5233, 68.5553, 66.2952, 54.8628, 
                 66.0116, 65.1014, 67.0548, 68.2222, 60.9956, 67.12, 60.1885, 72.7744, 56.3402, 54.1966], 
        'April': [54.7464, 58.5472, 57.4044, 72.7804, 61.3675, 56.2866, 68.5719, 60.0674, 56.8157, 67.3792, 
                  66.1168, 60.8252, 70.0377, 63.6455, 71.0847, 65.5137, 70.794, 63.547, 56.9013, 75.2468], 
        'Mai': [60.2711, 62.0058, 59.498, 61.983, 64.2133, 64.0092, 66.3051, 71.9608, 62.3977, 56.8344, 57.0884, 
                59.6712, 54.629, 67.1251, 60.5089, 61.4451, 62.9905, 56.0169, 58.6934, 66.3736, 66.0927], 
        'Juni': [60.7841, 72.0527, 56.4714, 61.2751, 61.8458, 49.0346, 72.6876, 64.8317, 57.7771, 73.2559, 
                 65.9283, 65.1476, 59.965, 63.5311, 55.3716, 66.9751, 61.1278, 63.6702, 69.0103]}
 
      #  for j in LAeq.values():
   #     print('höchsten Pegel im',i,max(j))
######################################
  #      for i in LAeq:
    #print(i)
   # print('höchsten Pegel im',i,max(LAeq.values()))
        # for j in LAeq.values():
######################################
#for i in LAeq:
 #   print('************')
  #  for j in LAeq.values():
   #     print('Im',i,'wurde ein maximaler Mittelungspegel von %.1f'%max(j),' dB gemessen.')
        ######################################
    #    Monat=0
#for i,j in LAeq:
 #   print('************')
  #  if Monat>6:
   #     break
    #for j in LAeq.values():
     #   Monat+=1
      #  print('Im',LAeq.keys(),'wurde ein maximaler Mittelungspegel von %.1f'%max(j),' dB gemessen.')   
    
print('# Hausaufgabe 1- ')
print('Beteuer :Gert Herold - Gruppe E :Shadi Kanaan & Mohamed Mesto')
print('Lärmbelastung am Arbeitsplatz')
print('************')
print('                                       ')
for i,j in LAeq.items():
    print('Im',i,'wurde ein maximaler Mittelungspegel von %.1f'%max(j),' dB gemessen.')
    print('************')
# Out:
# # Hausaufgabe 1-
# Beteuer :Gert Herold - Gruppe E :Shadi Kanaan & Mohamed Mesto
# Lärmbelastung am Arbeitsplatz
# ************
#
# Im Januar wurde ein maximaler Mittelungspegel von 73.9  dB gemessen.
# ************
# Im Februar wurde ein maximaler Mittelungspegel von 75.6  dB gemessen.
# ************
# Im März wurde ein maximaler Mittelungspegel von 72.8  dB gemessen.
# ************
# Im April wurde ein maximaler Mittelungspegel von 75.2  dB gemessen.
# ************
# Im Mai wurde ein maximaler Mittelungspegel von 72.0  dB gemessen.
# ************
# Im Juni wurde ein maximaler Mittelungspegel von 73.3  dB gemessen.
# ************

# %% [markdown]
# **2. Berechnen Sie für jeden Monat die Anzahl der Tage, an denen der zulässige Richtwert von 65 dB überschritten wurde und berechnen Sie deren prozentualen Anteil an der Gesamtzahl der Werktage im jeweiligen Monat.**
#
# Beispiel:
#
#     Juli    :  6 Tage (26.1 %)
#     August  :  9 Tage (40.9 %)
#
# <!-- Werktage Juli:23, August: 22 -->
#
#
# ** 2nd For each month, calculate the number of days that the allowed benchmark of 65 dB has been exceeded and calculate their percentage of the total number of working days in each month. **
#
# Example:
#
#      July: 6 days (26.1%)
#      August: 9 days (40.9%)
#
# <! - weekdays July: 23, August: 22 ->
#
# 2. Get number of days for each month with level higher than 65dB.

# %%
# Hier eigenen Code schreiben ...
print('# Hausaufgabe 2')
print('Beteuer :Gert Herold - Gruppe E :Shadi Kanaan & Mohamed Mesto')
print('*****Lärmbelastung am Arbeitsplatz*****')
print('                                       ')

LAeq = {'Januar': [65.6473, 63.6885, 63.3891, 66.0919, 64.1625, 66.4128, 61.4494, 50.8258, 68.1941, 73.9349, 65.2068, 
                   62.4992, 62.3178, 62.4047, 63.087, 57.3899, 60.4145, 58.0149, 64.244, 61.5168, 65.4761, 62.1265], 
        'Februar': [67.9317, 64.0677, 73.9535, 53.5182, 59.7654, 67.5074, 75.6416, 61.7568, 63.2183, 61.8684, 
                    69.6573, 61.5635, 66.4003, 61.401, 56.6372, 64.5677, 65.5159, 69.4661, 62.4478, 59.9132], 
        'März': [65.8138, 64.2037, 64.4033, 62.6344, 68.8017, 64.8475, 72.5233, 68.5553, 66.2952, 54.8628, 
                 66.0116, 65.1014, 67.0548, 68.2222, 60.9956, 67.12, 60.1885, 72.7744, 56.3402, 54.1966], 
        'April': [54.7464, 58.5472, 57.4044, 72.7804, 61.3675, 56.2866, 68.5719, 60.0674, 56.8157, 67.3792, 
                  66.1168, 60.8252, 70.0377, 63.6455, 71.0847, 65.5137, 70.794, 63.547, 56.9013, 75.2468], 
       'Mai': [60.2711, 62.0058, 59.498, 61.983, 64.2133, 64.0092, 66.3051, 71.9608, 62.3977, 56.8344, 57.0884, 
                59.6712, 54.629, 67.1251, 60.5089, 61.4451, 62.9905, 56.0169, 58.6934, 66.3736, 66.0927], 
        'Juni': [60.7841, 72.0527, 56.4714, 61.2751, 61.8458, 49.0346, 72.6876, 64.8317, 57.7771, 73.2559, 
                 65.9283, 65.1476, 59.965, 63.5311, 55.3716, 66.9751, 61.1278, 63.6702, 69.0103]}
 

#Summe_Tage:jeden Monat die Anzahl der Tage
#each month

#summe of the days
# >65db
#ercentage of the total number of working days in each month. 
Monaten=['Januar','Februar','März','April','Mai','Juni']
Summe_Tage=0
#überschritten={'Hocher_als_65':65.0000}
überschritten=[65]

Summe_Tage=0
Neue_List=[]
for Dic_Key in LAeq.keys():
    #for Dic_Val in LAeq.values():
    #print('************erste schleife')
    Neue_List=LAeq[Dic_Key].copy()
    #Neue_List=list(LAeq.values())
    #print('die Neue Liste',Neue_List)
     #if list(LAeq[Dic_Key])>überschritten:
     #if (LAeq[Dic_Key]>überschritten):
    Summe_Tage=0    
    for index, item in enumerate(Neue_List):
        if (item>65):
            Summe_Tage+=1
    #Anzahl Value>65        
    prozentualen=Summe_Tage*100/len(Neue_List)
    print('***********************************')
    print(Dic_Key,'  :  ',Summe_Tage,' Tage %.1f'%prozentualen,'%')
    
       
   
    
        #if (LAeq[Dic_Key]>überschritten):
       
    
    #print('hallo',Dic_Val)
   
    #for Dic_Val in LAeq.values():
     #list(d.values())  
     #   print('hallo',Dic_Val)  
    # print (list(LAeq.values()))
   # i=0
    #while i<len(LAeq.items()):
     #   print ('hallo-')
      #  i=i+1

print('************end Dic_Key')
# Out:
# # Hausaufgabe 2
# Beteuer :Gert Herold - Gruppe E :Shadi Kanaan & Mohamed Mesto
# *****Lärmbelastung am Arbeitsplatz*****
#
# ***********************************
# Januar   :   7  Tage 31.8 %
# ***********************************
# Februar   :   8  Tage 40.0 %
# ***********************************
# März   :   11  Tage 55.0 %
# ***********************************
# April   :   9  Tage 45.0 %
# ***********************************
# Mai   :   5  Tage 23.8 %
# ***********************************
# Juni   :   7  Tage 36.8 %
# ************end Dic_Key

# %% [markdown]
# **3. Durch intensive Lärmminderungsmaßnahmen könnte der Pegel um durchschnittlich 6 dB gesenkt werden. Schätzen Sie basierend auf den gegebenen Werten ab, wie viele (Werk-)Tage im Jahr es noch immer zu Richtwertüberschreitungen kommen würde. Wie sieht es bei 7 dB durchschnittlicher Pegelverringerung aus?**
#
#
# ** 3rd Intensive noise reduction measures could lower the level by an average of 6 dB. Based on the given values, estimate how many (work) days in the year there would still be guideline overruns. What about 7 dB average level reduction? **

# %%
# Hier eigenen Code schreiben ...
# Hier eigenen Code schreiben ...
print('# Hausaufgabe 3')
print('Beteuer :Gert Herold - Gruppe E :Shadi Kanaan & Mohamed Mesto')
print('*****Lärmbelastung am Arbeitsplatz*****')
print('                                       ')

LAeq = {'Januar': [65.6473, 63.6885, 63.3891, 66.0919, 64.1625, 66.4128, 61.4494, 50.8258, 68.1941, 73.9349, 65.2068, 
                   62.4992, 62.3178, 62.4047, 63.087, 57.3899, 60.4145, 58.0149, 64.244, 61.5168, 65.4761, 62.1265], 
        'Februar': [67.9317, 64.0677, 73.9535, 53.5182, 59.7654, 67.5074, 75.6416, 61.7568, 63.2183, 61.8684, 
                    69.6573, 61.5635, 66.4003, 61.401, 56.6372, 64.5677, 65.5159, 69.4661, 62.4478, 59.9132], 
        'März': [65.8138, 64.2037, 64.4033, 62.6344, 68.8017, 64.8475, 72.5233, 68.5553, 66.2952, 54.8628, 
                 66.0116, 65.1014, 67.0548, 68.2222, 60.9956, 67.12, 60.1885, 72.7744, 56.3402, 54.1966], 
        'April': [54.7464, 58.5472, 57.4044, 72.7804, 61.3675, 56.2866, 68.5719, 60.0674, 56.8157, 67.3792, 
                  66.1168, 60.8252, 70.0377, 63.6455, 71.0847, 65.5137, 70.794, 63.547, 56.9013, 75.2468], 
       'Mai': [60.2711, 62.0058, 59.498, 61.983, 64.2133, 64.0092, 66.3051, 71.9608, 62.3977, 56.8344, 57.0884, 
                59.6712, 54.629, 67.1251, 60.5089, 61.4451, 62.9905, 56.0169, 58.6934, 66.3736, 66.0927], 
        'Juni': [60.7841, 72.0527, 56.4714, 61.2751, 61.8458, 49.0346, 72.6876, 64.8317, 57.7771, 73.2559, 
                 65.9283, 65.1476, 59.965, 63.5311, 55.3716, 66.9751, 61.1278, 63.6702, 69.0103],
       'July': [65.6473, 63.6885, 63.3891, 66.0919, 64.1625, 66.4128, 61.4494, 50.8258, 68.1941, 73.9349, 65.2068, 
                   62.4992, 62.3178, 62.4047, 63.087, 57.3899, 60.4145, 58.0149, 64.244, 61.5168, 65.4761, 62.1265], 
        'Aug': [67.9317, 64.0677, 73.9535, 53.5182, 59.7654, 67.5074, 75.6416, 61.7568, 63.2183, 61.8684, 
                    69.6573, 61.5635, 66.4003, 61.401, 56.6372, 64.5677, 65.5159, 69.4661, 62.4478, 59.9132], 
        'Sep': [65.8138, 64.2037, 64.4033, 62.6344, 68.8017, 64.8475, 72.5233, 68.5553, 66.2952, 54.8628, 
                 66.0116, 65.1014, 67.0548, 68.2222, 60.9956, 67.12, 60.1885, 72.7744, 56.3402, 54.1966], 
        'oct': [54.7464, 58.5472, 57.4044, 72.7804, 61.3675, 56.2866, 68.5719, 60.0674, 56.8157, 67.3792, 
                  66.1168, 60.8252, 70.0377, 63.6455, 71.0847, 65.5137, 70.794, 63.547, 56.9013, 75.2468], 
       'Nov': [60.2711, 62.0058, 59.498, 61.983, 64.2133, 64.0092, 66.3051, 71.9608, 62.3977, 56.8344, 57.0884, 
                59.6712, 54.629, 67.1251, 60.5089, 61.4451, 62.9905, 56.0169, 58.6934, 66.3736, 66.0927], 
        'Dez': [60.7841, 72.0527, 56.4714, 61.2751, 61.8458, 49.0346, 72.6876, 64.8317, 57.7771, 73.2559, 
                 65.9283, 65.1476, 59.965, 63.5311, 55.3716, 66.9751, 61.1278, 63.6702, 69.0103]}
 
Summe_Tage=0
überschritten=[65]
Summe_Jahr=0/
Summe_Tage=0
Neue_List=[]
for Dic_Key in LAeq.keys():
    Neue_List=LAeq[Dic_Key].copy()
   
    Summe_Tage=0    
    for index, item in enumerate(Neue_List):
        item-=6
        if (item>65):
            #Summe_Tage+=1
            Summe_Jahr+=1
    #Anzahl Value>65        
    
    #prozentualen=Summe_Tage*100/len(Neue_List)
    #print('************')
   # print(Dic_Key,'  :  ',Summe_Tage,' Tage %.1f'%prozentualen,'%')
print('************')
print('im Jahr','  :  ',Summe_Jahr,'Tage')
print('**********')
# Out:
# # Hausaufgabe 3
# Beteuer :Gert Herold - Gruppe E :Shadi Kanaan & Mohamed Mesto
# *****Lärmbelastung am Arbeitsplatz*****
#
# ************
# im Jahr   :   24 Tage
# **********
